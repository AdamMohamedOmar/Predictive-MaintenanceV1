# %%
import pandas as pd; 
print(pd.__version__)
# Out:
# 2.2.3

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import xgboost
import torch
import shap
import obd
import streamlit
import onnxruntime
import pytest

print(f"Python:       {sys.version.split()[0]}")
print(f"pandas:       {pd.__version__}")
print(f"numpy:        {np.__version__}")
print(f"scikit-learn: {sklearn.__version__}")
print(f"xgboost:      {xgboost.__version__}")
print(f"torch:        {torch.__version__}")
print(f"shap:         {shap.__version__}")
print(f"obd:          {obd.__version__}")
print(f"streamlit:    {streamlit.__version__}")
print(f"onnxruntime:  {onnxruntime.__version__}")
# Out:
# Python:       3.11.9
# pandas:       2.2.3
# numpy:        1.26.4
# scikit-learn: 1.5.2
# xgboost:      2.1.3
# torch:        2.3.1+cpu
# shap:         0.46.0
# obd:          0.7.2
# streamlit:    1.38.0
# onnxruntime:  1.18.1

# %%
import sys
print(sys.executable)
# Out:
# d:\Predictive-MaintenanceV1\Predictive-MaintenanceV1\.venv\Scripts\python.exe
